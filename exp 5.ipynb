# %%
Exp no:5

# %%
#Aim:To perform operation on mean median mode

# %%
#Name:Komal G thakare
#Roll no:75
#Sec:c
#Subject:Et1
#Date:31/07/25

# %%
age=[ 1,2,3,4,5,6,7,8,9,12,13,14,14,13,12,12,13,16,87]

# %%
age
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 12, 13, 14, 14, 13, 12, 12, 13, 16.87]

# %%
import statistics

# %%
mean=statistics.mean(age)

# %%
mean
# Out:
# 9.159444444444444

# %%
median=statistics.mean(age)

# %%
median
# Out:
# 9.159444444444444

# %%
mode=statistics.mean(age)

# %%
mode
# Out:
# 9.159444444444444

# %%
import numpy as np
x=np.array([1,3,45,6,43,5,7,1,7,5,25,45,76])

# %%
x
# Out:
# array([ 1,  3, 45,  6, 43,  5,  7,  1,  7,  5, 25, 45, 76])

# %%
print(np.mean(x))
# Out:
# 20.692307692307693

# %%
print(np.median(x))
# Out:
# 7.0

# %%
print(np.mode(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(np.mode(x))
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(1), count=np.int64(2))

# %%
from scipy import stats

data = [10, 20, 30, 40, 50]
std_dev = stats.tstd(data)

print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 15.811388300841896

# %%
from scipy import stats

data = [10, 20, 30, 40, 50]
variance = stats.tvar(data)

print("Variance:", variance)
# Out:
# Variance: 250.0

# %%
# A 3x3 2D array
arr = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(arr)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
